# %%
import reverse_geocoder as rg
import pandas as pd

# %%
df = pd.read_csv("nigeria_health_facilities_osm.csv")

# %%
# only keep rows where osm_type = node
df = df[df["osm_type"] == "node"]
# Out:
#             X          Y      osm_id osm_type  completeness  \
# 0   11.661990  10.570679  3667918153     node            21
# 4    5.238671  12.992510  7820372217     node             9
# 11   4.710282   9.700989  8026244395     node            15
# 20  14.209675  11.355774  3678059623     node            21
# 26   3.394401   6.457865  4875180826     node            12
#
#     is_in_health_zone   amenity speciality addr_street operator  ...  \
# 0                 NaN   doctors        NaN         NaN      NaN  ...
# 4                 NaN  hospital        NaN         NaN      NaN  ...
# 11                NaN   doctors        NaN         NaN      NaN  ...
# 20                NaN    clinic        NaN         NaN      NaN  ...
# 26                NaN    clinic        NaN         NaN      NaN  ...
#
#                       name  staff_nurses changeset_user wheelchair beds  url  \
# 0       Limanti Dispensary             0          edvac        NaN  NaN  NaN
# ...

# %%
state_names = []

# get states each health facility is located in
for i, row in df.iterrows():
    X = row["X"]
    Y = row["Y"]
    state = rg.search((Y, X))[0]["admin1"]
    state_names.append(state)
    print("Finished", i)

# append to df
df["state_name"] = state_names
# Out:
# Finished 0
# Finished 4
# Finished 11
# Finished 20
# Finished 26
# Finished 28
# Finished 32
# Finished 35
# Finished 38
# Finished 39
# Finished 40
# Finished 44
# Finished 46
# Finished 48
# Finished 49
# Finished 51
# Finished 52
# Finished 55
# Finished 57
# Finished 59
# Finished 67
# Finished 69
# Finished 70
# Finished 77
# Finished 81
# Finished 88
# Finished 91
# Finished 93
# Finished 95
# Finished 97
# Finished 98
# Finished 100
# Finished 101
# Finished 103
# Finished 109
# Finished 110
# Finished 112
# Finished 113
# Finished 118
# Finished 119
# Finished 121
# Finished 126
# Finished 128
# Finished 138
# Finished 139
# Finished 146
# Finished 147
# Finished 153
# Finished 154
# Finished 159
# Finished 164
# Finished 166
# Finished 170
# Finished 172
# Finished 175
# Finished 183
# Finished 186
# Finished 192
# Finished 193
# Finished 199
# Finished 206
# Finished 208
# Finished 209
# Finished 212
# Finished 214
# Finished 219
# Finished 221
# Finished 228
# ...

# %%
df.to_csv("nigeria_health_facilities_osm_cleaned.csv")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=026e3cd0-6dd4-4df6-8f47-70e9153eff5e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
